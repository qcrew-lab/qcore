# %%
# ensure relative imports are correctly imported
import sys
sys.path.insert(0, '../')

# %%
import numpy as np
import matplotlib.pyplot as plt

from qm.QuantumMachinesManager import QuantumMachinesManager
from qm.QuantumMachine import QuantumMachine
from qm.qua import *

from instruments import LabBrick, MetaInstrument, Sa124
from instruments.quantum_machines.configuration import *

from measurements.routines import resonator_spectroscopy
from measurements.routines import resonator_power_level
from measurements.routines import qubit_spectroscopy
from measurements.routines import power_rabi
from measurements.routines import qubit_T1

# %%
# define a qubit
class Qubit(MetaInstrument):
    """
    Encapsulates a qubit.
    """
    def __init__(self, name: str, lo_freq: float):
        self.name = name
        self.lo_freq = lo_freq
    
    def _create_parameters(self):
        print("created dummy parameters for " + self.name)
    
    def _create_yaml_map(self):
        return {
            'lo_freq': self.lo_freq
        }

# instantiate the qubit
qubit = Qubit(name='qubit', lo_freq=4.36e9)

# %%
# define a resonator
class Resonator(MetaInstrument):
    """
    Encapsulates a resonator.
    """
    def __init__(self, name: str, lo_freq: float):
        self.name = name
        self.lo_freq = lo_freq
    
    def _create_parameters(self):
        print("created dummy parameters for " + self.name)
    
    def _create_yaml_map(self):
        return {
            'lo_freq': self.lo_freq
        }

# instantiate the resonator
rr = Resonator(name='rr', lo_freq=8.7571e9)

# %%
# start the qm
qmm = QuantumMachinesManager()
qm = qmm.open_qm(config)
# Out:
# 2021-04-21 09:25:37,796 - qm - INFO - Performing health check
# 2021-04-21 09:25:37,802 - qm - INFO - Health check passed

# %%
# We have tuned the IQ mixer according to the tutorial-2-2-SA124B-MixerTuning.ipynb document.
# These are key numbers obtained:
rr_dcOffsetI = 0.011558358245951837
rr_dcOffsetQ = -0.00947436793762317
rr_mixerGainCorrection = -0.15430981633780644
rr_mixerPhaseCorrection = 0.0212698142172309

q_dcOffsetI = -0.00647755186574999 
q_dcOffsetQ = -0.011624171790995147
q_mixerGainCorrection = -0.19547425898369505
q_mixerPhaseCorrection = 0.05154287262922243

# after this step we have tuned the IQ mixer.
qm.set_output_dc_offset_by_element("rr", "I", float(rr_dcOffsetI)) 
qm.set_output_dc_offset_by_element("rr", "Q", float(rr_dcOffsetQ))
qm.set_mixer_correction("mixer_rr", rr_IF, rr_LO, IQ_imbalance(rr_mixerGainCorrection, rr_mixerPhaseCorrection))
qm.set_output_dc_offset_by_element("qubit", "I", float(q_dcOffsetI)) 
qm.set_output_dc_offset_by_element("qubit", "Q", float(q_dcOffsetQ))
qm.set_mixer_correction("mixer_qubit", qubit_IF, qubit_LO, IQ_imbalance(rr_mixerGainCorrection, q_mixerPhaseCorrection))

# %%
# start the labbricks
lb_q = LabBrick(name='lb_q', serial_number=25331, element=qubit, power=15)
lb_rr = LabBrick(name='lb_rr', serial_number=25337, element=rr, power=13)
# Out:
# Trying to initialize lb_q
# Connnected to LabBrick 25331
# creating parameters...
# Initializing device...
# Successfully set frequency to 4.36E+09
# Successfully set power to +15
# Trying to initialize lb_rr
# Failed to connect to LabBrick.
# creating parameters...
# Initializing device...
# Failed to set frequency - out of bounds
# Failed to set power - out of bounds

# %%
sa = Sa124(name='sa', serial_number=19184645, center=8.7e9, span=200e6)
# Out:
# Trying to initialize sa
# Connnected to SA124B 19184645
# creating parameters...
# Configured sweep! Sweep info:
# {'center': 8700000000.0Hz, 'span': 200000000.0Hz, 'rbw': 250000.0Hz, 'ref_power': 0dBm, 'status': 0, 'sweep_length': 1000, 'start_freq': 8600100000.0, 'bin_size': 200000.0}

# %%
sa.disconnect()

# %%
freqs, amps = sa.sweep()
plt.plot(freqs, amps)

# %% [markdown]
# ### Resonator spectroscopy

# %%
F_START = -46.0e6
F_STOP = -52.0e6
F_STEP = -0.1e6
F_VEC = np.arange(F_START, F_STOP, F_STEP)
REPS = 2000
WAIT_TIME = 20000
rr_amp_scale = 0.9

I_list, Q_list = resonator_spectroscopy.run(qm, F_START, F_STOP, F_STEP, REPS, WAIT_TIME, 
                                            rr_amp_scale, qubit_amp_scale = None)
# Out:
# 2021-04-19 14:47:59,211 - qm - INFO - Flags:
# 2021-04-19 14:47:59,212 - qm - INFO - Executing high level program

# %%
amps = np.abs(I_list + 1j*Q_list)
freqs = F_VEC/1e6

plt.plot(freqs, amps)

# %% [markdown]
# ### Resonator power level sweep

# %%
REPS = 1000
AMP_START = 0.2
AMP_STOP = 0.9
AMP_STEP = 0.01
AMP_VEC = np.arange(AMP_START, AMP_STOP, AMP_STEP)
BUFFER_SIZE = len(AMP_VEC)
WAIT_TIME = 20000
rr_IF = -50e6

I_list, Q_list = resonator_power_level.run(qm, AMP_START, AMP_STOP, AMP_STEP, REPS, WAIT_TIME, 
                                           rr_IF, qubit_amp_scale = None)
# Out:
# <qm.QuantumMachine.QuantumMachine object at 0x0000016E6240A790>
# 0.2
# 2021-04-09 02:09:10,159 - qm - INFO - Flags:
# 2021-04-09 02:09:10,159 - qm - INFO - Executing high level program

# %%
contrast = np.abs(I_list + 1j*Q_list)
plt.figure(figsize=(10,8))
plt.plot(AMP_VEC, contrast)
plt.grid()

# %% [markdown]
# ### Qubit spectroscopy

# %%
F_START = -40.0e6
F_STOP = -60.0e6
F_STEP = -0.05e6
F_VEC = np.arange(F_START, F_STOP, F_STEP)
REPS = 6000
WAIT_TIME = 100000
rr_amp_scale = 0.02
rr_IF = -47.25e6
qubit_amp_scale = 1.
qubit_LO = 4.165e9
lb_q.frequency = qubit_LO

I_list, Q_list = qubit_spectroscopy.run(qm, F_START, F_STOP, F_STEP, REPS, WAIT_TIME, 
                                        rr_amp_scale, rr_IF, qubit_amp_scale)
# Out:
# Successfully set frequency to 4.16E+09
# 2021-04-12 00:30:30,542 - qm - INFO - Flags:
# 2021-04-12 00:30:30,542 - qm - INFO - Executing high level program

# %%
amps = np.abs(I_list + 1j*Q_list)
freqs = F_VEC/1e6

plt.figure(figsize=(15, 6), dpi=80)
plt.plot(freqs, amps)
plt.xlabel('Freq (MHz)')
plt.ylabel('|Amp|')
plt.grid()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Qubit spectroscopy with varying LO

# %%
qubit_LO_range = [4.170e9,]# 4.360e9, 4.542e9, 4.732e9, 4.922e9, 5.112e9, 5.302e9, 5.492e9]

F_START = 100e6
F_STOP = -100e6
F_STEP = -0.02e6
F_VEC = np.arange(F_START, F_STOP, F_STEP)
REPS = 4000
WAIT_TIME = 100000

rr_amp_scale = 0.02
rr_IF = -47.25e6
qubit_amp_scale = 1.25

# Each element of output_list corresponds to an LO value and is a dictionary containing I and Q lists 
output_list = []
for qubit_LO in qubit_LO_range:
    lb_q.frequency = qubit_LO
    I_list, Q_list = qubit_spectroscopy.run(qm, F_START, F_STOP, F_STEP, REPS, WAIT_TIME, 
                                            rr_amp_scale, rr_IF, qubit_amp_scale)
    output_list.append({'I': I_list, 'Q': Q_list})
# Out:
# Successfully set frequency to 4.17E+09
# 2021-04-10 18:41:04,670 - qm - INFO - Flags:
# 2021-04-10 18:41:04,671 - qm - INFO - Executing high level program

# %%
config['pulses']['saturation_pulse']
# Out:
# {'operation': 'control',
#  'length': 15000,
#  'waveforms': {'I': 'saturation_wf', 'Q': 'zero_wf'}}

# %%
for i, output in enumerate(output_list):
    I_list = output['I']
    Q_list = output['Q']
    amps = np.abs(I_list + 1j*Q_list)
    
    plt.figure(figsize=(15, 6), dpi=80)
    plt.plot(F_VEC/1e6, amps, )#marker='o', markersize=6, ls='')
    plt.title('Qubit_spec, 4k reps, 100us wait time \n sat. a=1.25, meas. a=0.02 (low power peak) and freq = -47.25MHz, tof = 824 ns, qubit_LO = %.3fGHz' % (qubit_LO_range[i]/1e9))
    plt.xlabel('Freq (MHz)')
    plt.ylabel('|Amp|')
    plt.grid()
    plt.legend()
    plt.savefig('qubit_spec_LO_%.3fGHz.png' % (qubit_LO_range[i]/1e9))
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Qubit Power Rabi

# %%
REPS = 6000
AMP_START = -1.6
AMP_STOP = 1.6
AMP_STEP = 0.01
WAIT_TIME = 100000
rr_amp_scale = 0.02
qubit_LO = 4.165e9
lb_q.frequency = qubit_LO

I_list, Q_list = power_rabi.run(qm, AMP_START, AMP_STOP, AMP_STEP, REPS, 
                                WAIT_TIME, rr_amp_scale, pulse = 'gaussian')
# Out:
# Successfully set frequency to 4.16E+09
# 2021-04-12 01:22:19,627 - qm - INFO - Flags:
# 2021-04-12 01:22:19,627 - qm - INFO - Executing high level program

# %%
amps = np.abs(I_list + 1j*Q_list)
AMP_VEC = np.arange(AMP_START, AMP_STOP, AMP_STEP)

plt.figure(figsize=(12, 8), dpi=80)
plt.plot(AMP_VEC, amps)

plt.xlabel('Amplitude scaling')
plt.ylabel('contrast')
plt.grid()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### T1 measurement

# %%
REPS = 4000
TAU_START = 24 
TAU_STOP = 50000
TAU_STEP = 100 
TAU_VEC = np.arange(TAU_START, TAU_STOP, TAU_STEP)
WAIT_TIME = 100000 # wait for cavity to relax to ground state

qubit_amp_scale = 1.0
rr_amp_scale = 0.02
qubit_LO = 4.165e9

lb_q.frequency = qubit_LO

I_list, Q_list = qubit_T1.run(qm, TAU_START, TAU_STOP, TAU_STEP, REPS, 
                                WAIT_TIME, rr_amp_scale, qubit_amp_scale)
# Out:
# Successfully set frequency to 4.16E+09
# 0.02 1.0
# 2021-04-12 02:17:02,548 - qm - INFO - Flags:
# 2021-04-12 02:17:02,548 - qm - INFO - Executing high level program

# %%
amps = np.abs(I_list + 1j*Q_list)
plt.figure(figsize=(12, 8), dpi=80)
plt.plot(TAU_VEC/1e3, amps)

#plt.title('Qubit_spec, -50MHz to -1MHz 0.2MHz step for 2k reps \n sat. a=0.7, meas. a=1.25 and freq = -49.80MHz, tof = 824 ns, qubit_LO = 4.382e9')
plt.xlabel(r'Delay ($\mu$s)')
plt.ylabel('contrast')
plt.grid()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Low-power readout contrast for different wait times

# %%
REPS = 8000
AMP_START = 0.001
AMP_STOP = 0.07
AMP_STEP = 0.0005
AMP_VEC = np.arange(AMP_START, AMP_STOP, AMP_STEP)
BUFFER_SIZE = len(AMP_VEC)
WAIT_TIME_list = [60000, 62500, 65000, 67500, 70000, 72500, 75000, 77500, 80000, 82500, 85000, 87500, 90000, 92500, 95000, 97500, 100000, 102500, 105000]
rr_IF = -47.25e6
qubit_amp_scale = 1.0
qubit_LO = 4.165e9
lb_q.frequency = qubit_LO

# Each element of output_list corresponds to an WAIT_TIME_list value and is a dictionary containing I and Q lists 
output_pi_pulse_list = []
output_zero_pulse_list = []

for WAIT_TIME in WAIT_TIME_list:
    
    I_list, Q_list = resonator_power_level.run(qm, AMP_START, AMP_STOP, AMP_STEP, REPS, WAIT_TIME, 
                                               rr_IF, qubit_amp_scale = qubit_amp_scale, pulse = 'gaussian')
    output_pi_pulse_list.append({'I': I_list, 'Q': Q_list})
    
    I_list, Q_list = resonator_power_level.run(qm, AMP_START, AMP_STOP, AMP_STEP, REPS, WAIT_TIME, 
                                               rr_IF, qubit_amp_scale = 0.00001, pulse = 'gaussian')
    output_zero_pulse_list.append({'I': I_list, 'Q': Q_list})
# Out:
# Successfully set frequency to 4.16E+09
# 2021-04-12 02:49:11,290 - qm - INFO - Flags:
# 2021-04-12 02:49:11,291 - qm - INFO - Executing high level program
# 2021-04-12 02:53:38,720 - qm - INFO - Flags:
# 2021-04-12 02:53:38,720 - qm - INFO - Executing high level program
# 2021-04-12 02:58:06,318 - qm - INFO - Flags:
# 2021-04-12 02:58:06,318 - qm - INFO - Executing high level program
# 2021-04-12 03:02:44,844 - qm - INFO - Flags:
# 2021-04-12 03:02:44,844 - qm - INFO - Executing high level program
# 2021-04-12 03:07:23,607 - qm - INFO - Flags:
# 2021-04-12 03:07:23,607 - qm - INFO - Executing high level program
# 2021-04-12 03:12:13,372 - qm - INFO - Flags:
# 2021-04-12 03:12:13,372 - qm - INFO - Executing high level program
# 2021-04-12 03:17:03,130 - qm - INFO - Flags:
# 2021-04-12 03:17:03,130 - qm - INFO - Executing high level program
# 2021-04-12 03:22:03,907 - qm - INFO - Flags:
# 2021-04-12 03:22:03,907 - qm - INFO - Executing high level program
# 2021-04-12 03:27:04,466 - qm - INFO - Flags:
# 2021-04-12 03:27:04,466 - qm - INFO - Executing high level program
# 2021-04-12 03:32:15,977 - qm - INFO - Flags:
# 2021-04-12 03:32:15,977 - qm - INFO - Executing high level program
# 2021-04-12 03:37:27,520 - qm - INFO - Flags:
# 2021-04-12 03:37:27,520 - qm - INFO - Executing high level program
# 2021-04-12 03:42:50,189 - qm - INFO - Flags:
# 2021-04-12 03:42:50,189 - qm - INFO - Executing high level program
# 2021-04-12 03:48:12,809 - qm - INFO - Flags:
# 2021-04-12 03:48:12,809 - qm - INFO - Executing high level program
# 2021-04-12 03:53:46,533 - qm - INFO - Flags:
# 2021-04-12 03:53:46,533 - qm - INFO - Executing high level program
# 2021-04-12 03:59:20,717 - qm - INFO - Flags:
# 2021-04-12 03:59:20,717 - qm - INFO - Executing high level program
# 2021-04-12 04:05:05,610 - qm - INFO - Flags:
# 2021-04-12 04:05:05,610 - qm - INFO - Executing high level program
# 2021-04-12 04:10:50,396 - qm - INFO - Flags:
# 2021-04-12 04:10:50,396 - qm - INFO - Executing high level program
# 2021-04-12 04:16:46,605 - qm - INFO - Flags:
# 2021-04-12 04:16:46,605 - qm - INFO - Executing high level program
# 2021-04-12 04:22:42,622 - qm - INFO - Flags:
# 2021-04-12 04:22:42,622 - qm - INFO - Executing high level program
# 2021-04-12 04:28:49,647 - qm - INFO - Flags:
# 2021-04-12 04:28:49,647 - qm - INFO - Executing high level program
# 2021-04-12 04:34:56,739 - qm - INFO - Flags:
# 2021-04-12 04:34:56,739 - qm - INFO - Executing high level program
# 2021-04-12 04:41:14,626 - qm - INFO - Flags:
# 2021-04-12 04:41:14,626 - qm - INFO - Executing high level program
# 2021-04-12 04:47:32,756 - qm - INFO - Flags:
# 2021-04-12 04:47:32,756 - qm - INFO - Executing high level program
# 2021-04-12 04:54:01,775 - qm - INFO - Flags:
# 2021-04-12 04:54:01,775 - qm - INFO - Executing high level program
# 2021-04-12 05:00:30,794 - qm - INFO - Flags:
# 2021-04-12 05:00:30,794 - qm - INFO - Executing high level program
# 2021-04-12 05:07:10,984 - qm - INFO - Flags:
# 2021-04-12 05:07:10,984 - qm - INFO - Executing high level program
# 2021-04-12 05:13:51,110 - qm - INFO - Flags:
# 2021-04-12 05:13:51,110 - qm - INFO - Executing high level program
# 2021-04-12 05:20:42,466 - qm - INFO - Flags:
# 2021-04-12 05:20:42,466 - qm - INFO - Executing high level program
# 2021-04-12 05:27:33,695 - qm - INFO - Flags:
# 2021-04-12 05:27:33,695 - qm - INFO - Executing high level program
# 2021-04-12 05:34:35,725 - qm - INFO - Flags:
# 2021-04-12 05:34:35,725 - qm - INFO - Executing high level program
# 2021-04-12 05:41:37,782 - qm - INFO - Flags:
# 2021-04-12 05:41:37,782 - qm - INFO - Executing high level program
# 2021-04-12 05:48:51,055 - qm - INFO - Flags:
# 2021-04-12 05:48:51,055 - qm - INFO - Executing high level program
# 2021-04-12 05:56:04,295 - qm - INFO - Flags:
# 2021-04-12 05:56:04,295 - qm - INFO - Executing high level program
# 2021-04-12 06:03:28,664 - qm - INFO - Flags:
# 2021-04-12 06:03:28,664 - qm - INFO - Executing high level program
# 2021-04-12 06:10:52,804 - qm - INFO - Flags:
# 2021-04-12 06:10:52,804 - qm - INFO - Executing high level program
# 2021-04-12 06:18:28,082 - qm - INFO - Flags:
# 2021-04-12 06:18:28,082 - qm - INFO - Executing high level program
# 2021-04-12 06:26:03,201 - qm - INFO - Flags:
# 2021-04-12 06:26:03,201 - qm - INFO - Executing high level program
# 2021-04-12 06:33:49,346 - qm - INFO - Flags:
# 2021-04-12 06:33:49,346 - qm - INFO - Executing high level program

# %%
plt.figure(figsize=(15, 8), dpi=80)

index_list = [4, 16]
for i, output in enumerate(output_pi_pulse_list):
    if i not in index_list:
        continue
    I_list = output_pi_pulse_list[i]['I']
    Q_list = output_pi_pulse_list[i]['Q']
    I_list_0 = output_zero_pulse_list[i]['I']
    Q_list_0 = output_zero_pulse_list[i]['Q']
    
    amps = np.abs(I_list + 1j*Q_list)
    amps_0 = np.abs(I_list_0 + 1j*Q_list_0)
    
    plt.plot(AMP_VEC, amps_0 - amps, label = '%.1f us' % (WAIT_TIME_list[i]/1e3))#marker='o', markersize=6, ls='')

plt.title('Low-power readout contrast as a function of RO amplitude scaling and wait time.\n 8k reps, meas. f = -47.25e6 and 1us pulse length, tof = 824 ns')
plt.xlabel('Freq (MHz)')
plt.ylabel('|Amp|')
plt.grid()
plt.legend()
plt.savefig('qubit_spec_LO_%.dGHz.png' % (WAIT_TIME_list[i]))

# %%
# play CW on qm
with program() as cw:
    with infinite_loop_():
        play('CW', qubit.name)
        play('CW', rr.name)
job = qm.execute(cw)

# %%
# connect to the spectrum analyzer
sa = Sa124(name = 'sa', serial_number = 19184645)

# %%
# acquire spectrum
sa.configure_sweep(center = qubit.lo_freq, span = 100e6)
freqs, amps = sa.sweep()
plt.plot(freqs, amps)

# %%
# acquire another spectrum
sa.configure_sweep(center=6e9, span=250e6)
freqs, amps = sa.sweep()
plt.plot(freqs, amps)

# %%
sa.disconnect()
job.halt()

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-f7d9ed835a5c> in <module>
# ----> 1 qm.list_controllers()
#
# ~\anaconda3\envs\qcrew\lib\site-packages\qm\QuantumMachine.py in list_controllers(self)
#     178         :return: The names of the controllers configured in this qm
#     179         """
# --> 180         return tuple(self.get_config()["controllers"].keys())
#     181
#     182     def set_mixer_correction(self, mixer, intermediate_frequency, lo_frequency, values):
#
# ~\anaconda3\envs\qcrew\lib\site-packages\qm\QuantumMachine.py in get_config(self)
#     863         :return: A dictionary with the qm's config
#     864         """
# --> 865         configs = self._manager._get_qm_config(self._id)
#     866         self._pb_config = configs["pb_config"]
#     867         self._config = configs["config"]
#
# ~\anaconda3\envs\qcrew\lib\site-packages\qm\QuantumMachinesManager.py in _get_qm_config(self, machine_id)
#     376             result = self._frontend.GetQuantumMachine(request)
#     377             if not result.success:
# --> 378                 self._raise_get_qm_errors(result)
#     379             return {
#     380                 "pb_config": result.config,
#
# ~\anaconda3\envs\qcrew\lib\site-packages\qm\QuantumMachinesManager.py in _raise_get_qm_errors(self, result)
#     388         exception = Exception(error_str)
#     389         exception.errors = [(it.code, it.message) for it in result.errors]
# --> 390         raise exception
#     391
#     392     def close_all_quantum_machines(self):
#
# Exception: Machine does not exist
